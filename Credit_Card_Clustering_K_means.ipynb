# %% [markdown]
# <a href="https://colab.research.google.com/github/Cvelsen22/Carmelo-Velez---Data-Analysis-Portfolio/blob/main/Credit_Card_Clustering_K_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About Dataset
# This case requires to develop a customer segmentation to define marketing strategy. The
# sample Dataset summarizes the usage behavior of about 9000 active credit card holders during the last 6 months. The file is at a customer level with 18 behavioral variables.
#
# Following is the Data Dictionary for Credit Card dataset :-
#
# * CUST_ID : Identification of Credit Card holder (Categorical)
# * BALANCE : Balance amount left in their account to make purchases (
# * BALANCE_FREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# * PURCHASES : Amount of purchases made from account
# * ONEOFF_PURCHASES : Maximum purchase amount done in one-go
# * INSTALLMENTS_PURCHASES : Amount of purchase done in installment
# * CASH_ADVANCE : Cash in advance given by the user
# * PURCHASES_FREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# * ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# * PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# * CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
# * CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
# * PURCHASES_TRX : Numbe of purchase transactions made
# * CREDIT_LIMIT : Limit of Credit Card for user
# * PAYMENTS : Amount of Payment done by user
# *MINIMUM_PAYMENTS : Minimum amount of payments made by user
# * PRCFULLPAYMENT : Percent of full payment paid by user
# * TENURE : Tenure of credit card service for user

# %%
# Import Required Packages
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Read in dataset
cc = pd.read_csv("CC_GENERAL.csv")

# %%
cc.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
missing = cc.isna().sum()
print(missing)
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
cc_no_duplicates = cc.dropna()
cc_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8636 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8636 non-null   object
#  1   BALANCE                           8636 non-null   float64
#  2   BALANCE_FREQUENCY                 8636 non-null   float64
#  3   PURCHASES                         8636 non-null   float64
#  4   ONEOFF_PURCHASES                  8636 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8636 non-null   float64
#  6   CASH_ADVANCE                      8636 non-null   float64
#  7   PURCHASES_FREQUENCY               8636 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8636 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8636 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8636 non-null   float64
# ...

# %% [markdown]
# # Exploratory analysis

# %%
cc_no_duplicates.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8636.000000        8636.000000   8636.000000       8636.000000
# mean    1601.224893           0.895035   1025.433874        604.901438
# std     2095.571300           0.207697   2167.107984       1684.307803
# min        0.000000           0.000000      0.000000          0.000000
# 25%      148.095189           0.909091     43.367500          0.000000
# 50%      916.855459           1.000000    375.405000         44.995000
# 75%     2105.195853           1.000000   1145.980000        599.100000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8636.000000   8636.000000          8636.000000
# mean               420.843533    994.175523             0.496000
# std                917.245182   2121.458303             0.401273
# min                  0.000000      0.000000             0.000000
# ...

# %%
fig , ax = plt.subplots(1,5,figsize=(20,4))
cols = ['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']
for i,col in enumerate(cols):
    sns.boxplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 color = 'green'
                )
    ax[i].set_title(f'{col} Box Plot')
fig.show()

# %%
fig , ax = plt.subplots(1,5,figsize=(20,5))
cols = ['CASH_ADVANCE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY']
for i,col in enumerate(cols):
    sns.boxplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 color = 'green'
                )
    ax[i].set_title(f'{col} Box Plot')
fig.show()

# %%
fig , ax = plt.subplots(1,6,figsize=(20,5))
cols = ['CASH_ADVANCE_TRX','CREDIT_LIMIT','PAYMENTS','MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']
for i,col in enumerate(cols):
    sns.boxplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 color = 'green'
                )
    ax[i].set_title(f'{col} Box Plot')
fig.show()

# %%
fig , ax = plt.subplots(1,5,figsize=(20,4))
cols = ['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']
for i,col in enumerate(cols):
    sns.histplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 kde=True,
                 color = 'green'
                )
    ax[i].set_title(f'{col} Distribution')
fig.show()

# %%
fig , ax = plt.subplots(1,5,figsize=(20,4))
cols = ['CASH_ADVANCE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY']
for i,col in enumerate(cols):
    sns.histplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 kde=True,
                 color = 'green'
                )
    ax[i].set_title(f'{col} Distribution')
fig.show()

# %%
fig , ax = plt.subplots(1,6,figsize=(20,4))
cols = ['CASH_ADVANCE_TRX','CREDIT_LIMIT','PAYMENTS','MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']
for i,col in enumerate(cols):
    sns.histplot(cc_no_duplicates,
                 x=col,
                 ax=ax[i],
                 kde=True,
                 color = 'green'
                )
    ax[i].set_title(f'{col} Distribution')
fig.show()

# %% [markdown]
# # preprocessing

# %%
cc_data = cc_no_duplicates.drop(['CUST_ID'], axis = 1)

# %%
# Perform preprocessing steps on the dataset - scaling
scaler = StandardScaler()
X = scaler.fit_transform(cc_data)
cc_preprocessed = pd.DataFrame(data=X,columns=cc_data.columns)
cc_preprocessed.head(10)
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.744625          -0.370047  -0.429184         -0.359160
# 1  0.764152           0.067679  -0.473208         -0.359160
# 2  0.426602           0.505405  -0.116413          0.099909
# 3 -0.373910           0.505405  -0.465825         -0.349660
# 4  0.099551           0.505405   0.142062         -0.359160
# 5 -0.464799           0.505405   2.799089          3.442402
# 6  0.106148           0.505405  -0.271914         -0.359160
# 7 -0.279796           0.505405  -0.075655          0.033599
# 8 -0.691498          -1.683224   0.118213          0.401790
# 9 -0.147033           0.505405  -0.048599         -0.359160
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.354826     -0.468655            -0.820769
# 1               -0.458839      2.568556            -1.236139
# 2               -0.458839     -0.468655             1.256077
# ...

# %% [markdown]
# # PCA

# %%
# Perform PCA
pca = PCA(n_components=None)
cc_pca = pca.fit(cc_preprocessed)
cc_pca.explained_variance_ratio_
n_components=sum(cc_pca.explained_variance_ratio_>0.1)
pca = PCA(n_components=n_components)
cc_PCA = pca.fit_transform(cc_preprocessed)

# %% [markdown]
# # The first principal component

# %%
# Make a scatter plot of the untransformed points
plt.scatter(X[:,0], X[:,1])
# Get the mean of the grain samples: mean
mean = cc_pca.mean_
# Get the first principal component: first_pc
first_pc = pca.components_[0,:]
# Plot first_pc as an arrow, starting at mean
plt.arrow(mean[0], mean[1], first_pc[0], first_pc[1], color='red', width=0.07)
# Keep axes on same scale
plt.axis('equal')
plt.show()

# %% [markdown]
# # Variance of the PCA features

# %%
# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %% [markdown]
# Elbow Method

# %%
# Detect the optimal number of clusters for k-means clustering
inertia = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(cc_PCA)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
n_clusters=4
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# # k-means clustering

# %%
# Run the k-means clustering algorithm
# with the optimal number of clusters
# and visualize the resulting clusters.
kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(cc_PCA)
plt.scatter(cc_PCA[:, 0], cc_PCA[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title(f'K-means Clustering (K={n_clusters})')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # statistical values for each cluster

# %%
# Create a final statistical DataFrame for each cluster.
cc_data['label'] = kmeans.labels_
numeric_columns = ['BALANCE', 'BALANCE_FREQUENCY','PURCHASES','ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','CASH_ADVANCE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY','CASH_ADVANCE_TRX','PURCHASES_TRX','CREDIT_LIMIT','PAYMENTS','MINIMUM_PAYMENTS','PRC_FULL_PAYMENT','TENURE']
stat_cc = cc_data[numeric_columns].groupby(kmeans.labels_).mean()
stat_cc
# Out:
#        BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# 0   828.995048           0.929811  1266.399474        639.528110
# 1  1070.532316           0.830285   226.651743        157.670549
# 2  3474.272110           0.987923  7021.550705       4607.752801
# 3  4550.462900           0.965763   461.507978        298.200646
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0              627.081043    146.671409             0.863864
# 1               69.326434    631.085780             0.194961
# 2             2415.042718    799.845292             0.953150
# 3              163.409793   4450.671444             0.266055
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.306704                          0.676401
# 1                    0.076566                          0.112913
# 2                    0.725824                          0.809440
# 3                    0.130302                          0.166241
#
# ...
